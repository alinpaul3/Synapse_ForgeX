# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# This notebook performs exploratory data analysis on the personality detector dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# Load data
data_path = Path('../data/processed_input')
print(f'Data directory: {data_path}')
print(f'Files available: {list(data_path.glob("*"))}')

# %% [markdown]
# ## Data Overview

# %%
# Load your data here
# df = pd.read_csv(data_path / 'your_data.csv')

# Display basic information
# print(df.info())
# print(df.describe())
# print(f'Shape: {df.shape}')
# print(f'Missing values:\n{df.isnull().sum()}')

# %% [markdown]
# ## Distribution Analysis

# %%
# Analyze distributions of key features
# df.hist(bins=30, figsize=(15, 10))
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
# Analyze correlations between features
# correlation_matrix = df.corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.title('Feature Correlation Matrix')
# plt.show()
